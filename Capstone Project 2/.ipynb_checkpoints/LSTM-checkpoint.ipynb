# %%
from __future__ import print_function
import numpy as np

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils

from pandas import read_csv
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler


def data():
    
    dataset = read_csv('data/train.csv', index_col='Date')
    
    X = dataset.drop(labels=['close_nextday', 'close'], axis=1)
    y = dataset['close_nextday']
    
    
    tss = TimeSeriesSplit(n_splits=3)  # n_splits = 3-1...2 splits - 75% train, 25% test

    for train_index, test_index in tss.split(X):
        X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    # Reshape y train, test to match X train, test

    y_train = y_train.values.reshape(-1, 1)
    y_test = y_test.values.reshape(-1, 1)
    
    
    ss = StandardScaler()

    X_train = ss.fit_transform(X_train)
    X_test = ss.fit_transform(X_test)
    y_train = ss.fit_transform(y_train)
    y_test = ss.fit_transform(y_test)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
    y_train = y_train.reshape(y_train.shape[0], 1, 1)
    y_test = y_test.reshape(y_test.shape[0], 1, 1)
    
    n_features = X.shape[1]
    n_input = y_train.shape[0]
    
    return X_train, X_test, y_train, y_test

def model(X_train, X_test, y_train, y_test):

    model = Sequential()
    model.add(LSTM(128, input_shape=(n_input, n_features)))
    model.add(Activation({{choice(['relu', 'sigmoid', 'linear', 'softmax'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))

    model.compile(loss='mse',
                  optimizer={{choice(['rmsprop', 'adam', 'sgd', 'nadam'])}},
                  metrics=['mse'])

    result = model.fit(X_train,
                       y_train,
                       batch_size={{choice([12, 24, 64, 128])}},
                       epochs={{choice([100, 200, 300, 400, 500])}},
                       verbose=2,
                       validation_data=(X_test, y_test))
                       

    score, mse = model.evaluate(X_test, y_test, verbose=0)
    print('Test accuracy:', mse)
    return {'loss': mse, 'status': STATUS_OK, 'model': model}


if __name__ == '__main__':
    trials = Trials()
    best_run, best_model = optim.minimize(model=model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=10,
                                          trials=trials,
                                          notebook_name="LSTM")
    
    for trial in trials:
        print(trial)
    
    X_train, y_train, X_test, y_test = data()
    print("Evalutation of best performing model:")
    print(best_model.evaluate(X_test, y_test))
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.preprocessing import sequence
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.layers.embeddings import Embedding
# except:
#     pass
#
# try:
#     from keras.layers.recurrent import LSTM
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# try:
#     from sklearn.model_selection import TimeSeriesSplit
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid', 'linear', 'softmax']),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam', 'sgd', 'nadam']),
#         'batch_size': hp.choice('batch_size', [12, 24, 64, 128]),
#         'epochs': hp.choice('epochs', [100, 200, 300, 400, 500]),
#     }
#
# >>> Data
#   1:
#   2:
#   3: dataset = read_csv('data/train.csv', index_col='Date')
#   4:
#   5: X = dataset.drop(labels=['close_nextday', 'close'], axis=1)
#   6: y = dataset['close_nextday']
#   7:
#   8:
#   9: tss = TimeSeriesSplit(n_splits=3)  # n_splits = 3-1...2 splits - 75% train, 25% test
#  10:
#  11: for train_index, test_index in tss.split(X):
#  12:     X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
#  13:     y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#  14:
#  15: # Reshape y train, test to match X train, test
#  16:
#  17: y_train = y_train.values.reshape(-1, 1)
#  18: y_test = y_test.values.reshape(-1, 1)
#  19:
#  20:
#  21: ss = StandardScaler()
#  22:
#  23: X_train = ss.fit_transform(X_train)
#  24: X_test = ss.fit_transform(X_test)
#  25: y_train = ss.fit_transform(y_train)
#  26: y_test = ss.fit_transform(y_test)
#  27:
#  28: X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
#  29: X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
#  30: y_train = y_train.reshape(y_train.shape[0], 1, 1)
#  31: y_test = y_test.reshape(y_test.shape[0], 1, 1)
#  32:
#  33: n_features = X.shape[1]
#  34: n_input = y_train.shape[0]
#  35:
#  36:
#  37:
#  38:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:
#   4:     model = Sequential()
#   5:     model.add(LSTM(128, input_shape=(n_input, n_features)))
#   6:     model.add(Activation(space['Activation']))
#   7:     model.add(Dropout(space['Dropout']))
#   8:     model.add(Dense(1))
#   9:
#  10:     model.compile(loss='mse',
#  11:                   optimizer=space['optimizer'],
#  12:                   metrics=['mse'])
#  13:
#  14:     result = model.fit(X_train,
#  15:                        y_train,
#  16:                        batch_size=space['batch_size'],
#  17:                        epochs=space['epochs'],
#  18:                        verbose=2,
#  19:                        validation_data=(X_test, y_test))
#  20:
#  21:
#  22:     score, mse = model.evaluate(X_test, y_test, verbose=0)
#  23:     print('Test accuracy:', mse)
#  24:     return {'loss': mse, 'status': STATUS_OK, 'model': model}
#  25:
# Epoch 1/200
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:Model was constructed with shape (None, 331, 6) for input KerasTensor(type_spec=TensorSpec(shape=(None, 331, 6), dtype=tf.float32, name='lstm_1_input'), name='lstm_1_input', description="created by layer 'lstm_1_input'"), but it was called on an input with incompatible shape (None, 1, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 331, 6) for input KerasTensor(type_spec=TensorSpec(shape=(None, 331, 6), dtype=tf.float32, name='lstm_1_input'), name='lstm_1_input', description="created by layer 'lstm_1_input'"), but it was called on an input with incompatible shape (None, 1, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 331, 6) for input KerasTensor(type_spec=TensorSpec(shape=(None, 331, 6), dtype=tf.float32, name='lstm_1_input'), name='lstm_1_input', description="created by layer 'lstm_1_input'"), but it was called on an input with incompatible shape (None, 1, 6).
# 28/28 - 3s - loss: 1.9134 - mse: 1.9134 - val_loss: 0.9874 - val_mse: 0.9874
#
# Epoch 2/200
# 28/28 - 0s - loss: 1.5692 - mse: 1.5692 - val_loss: 1.0580 - val_mse: 1.0580
#
# Epoch 3/200
# 28/28 - 0s - loss: 1.2644 - mse: 1.2644 - val_loss: 1.0227 - val_mse: 1.0227
#
# Epoch 4/200
# 28/28 - 0s - loss: 1.2642 - mse: 1.2642 - val_loss: 1.4339 - val_mse: 1.4339
#
# Epoch 5/200
# 28/28 - 0s - loss: 1.2139 - mse: 1.2139 - val_loss: 0.9839 - val_mse: 0.9839
#
# Epoch 6/200
# 28/28 - 0s - loss: 1.1674 - mse: 1.1674 - val_loss: 1.0470 - val_mse: 1.0470
#
# Epoch 7/200
# 28/28 - 0s - loss: 1.0971 - mse: 1.0971 - val_loss: 1.0161 - val_mse: 1.0161
#
# Epoch 8/200
# 28/28 - 0s - loss: 1.1064 - mse: 1.1064 - val_loss: 1.1156 - val_mse: 1.1156
#
# Epoch 9/200
# 28/28 - 0s - loss: 1.1432 - mse: 1.1432 - val_loss: 1.1518 - val_mse: 1.1518
#
# Epoch 10/200
# 28/28 - 0s - loss: 1.0965 - mse: 1.0965 - val_loss: 1.0129 - val_mse: 1.0129
#
# Epoch 11/200
# 28/28 - 0s - loss: 1.0777 - mse: 1.0777 - val_loss: 1.0331 - val_mse: 1.0331
#
# Epoch 12/200
# 28/28 - 0s - loss: 1.0395 - mse: 1.0395 - val_loss: 1.0274 - val_mse: 1.0274
#
# Epoch 13/200
# 28/28 - 0s - loss: 1.1214 - mse: 1.1214 - val_loss: 1.0535 - val_mse: 1.0535
#
# Epoch 14/200
# 28/28 - 0s - loss: 1.1634 - mse: 1.1634 - val_loss: 0.9892 - val_mse: 0.9892
#
# Epoch 15/200
# 28/28 - 0s - loss: 1.0873 - mse: 1.0873 - val_loss: 0.9944 - val_mse: 0.9944
#
# Epoch 16/200
# 28/28 - 0s - loss: 1.0876 - mse: 1.0876 - val_loss: 0.9984 - val_mse: 0.9984
#
# Epoch 17/200
# 28/28 - 0s - loss: 1.1159 - mse: 1.1159 - val_loss: 1.2458 - val_mse: 1.2458
#
# Epoch 18/200
# 28/28 - 0s - loss: 1.1684 - mse: 1.1684 - val_loss: 1.0636 - val_mse: 1.0636
#
# Epoch 19/200
# 28/28 - 0s - loss: 1.1265 - mse: 1.1265 - val_loss: 1.0047 - val_mse: 1.0047
#
# Epoch 20/200
# 28/28 - 0s - loss: 1.1105 - mse: 1.1105 - val_loss: 0.9977 - val_mse: 0.9977
#
# Epoch 21/200
# 28/28 - 0s - loss: 1.0534 - mse: 1.0534 - val_loss: 1.0191 - val_mse: 1.0191
#
# Epoch 22/200
# 28/28 - 0s - loss: 1.0981 - mse: 1.0981 - val_loss: 1.0146 - val_mse: 1.0146
#
# Epoch 23/200
# 28/28 - 0s - loss: 1.1486 - mse: 1.1486 - val_loss: 1.0056 - val_mse: 1.0056
#
# Epoch 24/200
# 28/28 - 0s - loss: 1.0878 - mse: 1.0878 - val_loss: 1.0972 - val_mse: 1.0972
#
# Epoch 25/200
# 28/28 - 0s - loss: 1.0798 - mse: 1.0798 - val_loss: 1.0362 - val_mse: 1.0362
#
# Epoch 26/200
# 28/28 - 0s - loss: 1.1349 - mse: 1.1349 - val_loss: 1.0438 - val_mse: 1.0438
#
# Epoch 27/200
# 28/28 - 0s - loss: 1.1054 - mse: 1.1054 - val_loss: 0.9987 - val_mse: 0.9987
#
# Epoch 28/200
# 28/28 - 0s - loss: 1.0933 - mse: 1.0933 - val_loss: 0.9898 - val_mse: 0.9898
#
# Epoch 29/200
# 28/28 - 0s - loss: 1.1175 - mse: 1.1175 - val_loss: 1.0648 - val_mse: 1.0648
#
# Epoch 30/200
# 28/28 - 0s - loss: 1.1675 - mse: 1.1675 - val_loss: 0.9861 - val_mse: 0.9861
#
# Epoch 31/200
# 28/28 - 0s - loss: 1.0803 - mse: 1.0803 - val_loss: 0.9930 - val_mse: 0.9930
#
# Epoch 32/200
# 28/28 - 0s - loss: 1.0919 - mse: 1.0919 - val_loss: 0.9846 - val_mse: 0.9846
#
# Epoch 33/200
# 28/28 - 0s - loss: 1.1293 - mse: 1.1293 - val_loss: 1.3291 - val_mse: 1.3291
#
# Epoch 34/200
# 28/28 - 0s - loss: 1.1037 - mse: 1.1037 - val_loss: 1.0384 - val_mse: 1.0384
#
# Epoch 35/200
# 28/28 - 0s - loss: 1.1282 - mse: 1.1282 - val_loss: 1.0241 - val_mse: 1.0241
#
# Epoch 36/200
# 28/28 - 0s - loss: 1.1064 - mse: 1.1064 - val_loss: 1.1885 - val_mse: 1.1885
#
# Epoch 37/200
# 28/28 - 0s - loss: 1.0941 - mse: 1.0941 - val_loss: 1.1502 - val_mse: 1.1502
#
# Epoch 38/200
# 28/28 - 0s - loss: 1.1731 - mse: 1.1731 - val_loss: 1.0131 - val_mse: 1.0131
#
# Epoch 39/200
# 28/28 - 0s - loss: 1.0945 - mse: 1.0945 - val_loss: 0.9839 - val_mse: 0.9839
#
# Epoch 40/200
# 28/28 - 0s - loss: 1.0982 - mse: 1.0982 - val_loss: 1.0268 - val_mse: 1.0268
#
# Epoch 41/200
# 28/28 - 0s - loss: 1.0691 - mse: 1.0691 - val_loss: 1.0641 - val_mse: 1.0641
#
# Epoch 42/200
# 28/28 - 0s - loss: 1.1145 - mse: 1.1145 - val_loss: 0.9798 - val_mse: 0.9798
#
# Epoch 43/200
# 28/28 - 0s - loss: 1.0974 - mse: 1.0974 - val_loss: 1.0278 - val_mse: 1.0278
#
# Epoch 44/200
# 28/28 - 0s - loss: 1.0921 - mse: 1.0921 - val_loss: 1.1155 - val_mse: 1.1155
#
# Epoch 45/200
# 28/28 - 0s - loss: 1.1017 - mse: 1.1017 - val_loss: 0.9880 - val_mse: 0.9880
#
# Epoch 46/200
# 28/28 - 0s - loss: 1.1007 - mse: 1.1007 - val_loss: 0.9891 - val_mse: 0.9891
#
# Epoch 47/200
# 28/28 - 0s - loss: 1.1491 - mse: 1.1491 - val_loss: 1.1621 - val_mse: 1.1621
#
# Epoch 48/200
# 28/28 - 0s - loss: 1.1863 - mse: 1.1863 - val_loss: 1.2915 - val_mse: 1.2915
# Epoch 49/200
# 28/28 - 0s - loss: 1.0620 - mse: 1.0620 - val_loss: 0.9874 - val_mse: 0.9874
#
# Epoch 50/200
# 28/28 - 0s - loss: 1.0540 - mse: 1.0540 - val_loss: 0.9957 - val_mse: 0.9957
#
# Epoch 51/200
# 28/28 - 0s - loss: 1.0927 - mse: 1.0927 - val_loss: 1.0943 - val_mse: 1.0943
#
# Epoch 52/200
# 28/28 - 0s - loss: 1.0692 - mse: 1.0692 - val_loss: 1.0812 - val_mse: 1.0812
#
# Epoch 53/200
# 28/28 - 0s - loss: 1.1452 - mse: 1.1452 - val_loss: 0.9939 - val_mse: 0.9939
#
# Epoch 54/200
# 28/28 - 0s - loss: 1.0727 - mse: 1.0727 - val_loss: 0.9975 - val_mse: 0.9975
#
# Epoch 55/200
# 28/28 - 0s - loss: 1.0409 - mse: 1.0409 - val_loss: 1.2120 - val_mse: 1.2120
#
# Epoch 56/200
# 28/28 - 0s - loss: 1.1392 - mse: 1.1392 - val_loss: 0.9840 - val_mse: 0.9840
#
# Epoch 57/200
# 28/28 - 0s - loss: 1.1159 - mse: 1.1159 - val_loss: 1.5311 - val_mse: 1.5311
#
# Epoch 58/200
# 28/28 - 0s - loss: 1.0968 - mse: 1.0968 - val_loss: 0.9864 - val_mse: 0.9864
#
# Epoch 59/200
# 28/28 - 0s - loss: 1.0716 - mse: 1.0716 - val_loss: 0.9813 - val_mse: 0.9813
#
# Epoch 60/200
# 28/28 - 0s - loss: 1.0623 - mse: 1.0623 - val_loss: 1.0830 - val_mse: 1.0830
#
# Epoch 61/200
# 28/28 - 0s - loss: 1.1838 - mse: 1.1838 - val_loss: 0.9889 - val_mse: 0.9889
#
# Epoch 62/200
# 28/28 - 0s - loss: 1.0686 - mse: 1.0686 - val_loss: 1.1155 - val_mse: 1.1155
#
# Epoch 63/200
# 28/28 - 0s - loss: 1.0968 - mse: 1.0968 - val_loss: 1.0609 - val_mse: 1.0609
#
# Epoch 64/200
# 28/28 - 0s - loss: 1.0661 - mse: 1.0661 - val_loss: 1.0518 - val_mse: 1.0518
#
# Epoch 65/200
# 28/28 - 0s - loss: 1.0255 - mse: 1.0255 - val_loss: 0.9778 - val_mse: 0.9778
#
# Epoch 66/200
# 28/28 - 0s - loss: 1.0966 - mse: 1.0966 - val_loss: 1.0673 - val_mse: 1.0673
#
# Epoch 67/200
# 28/28 - 0s - loss: 1.1776 - mse: 1.1776 - val_loss: 1.1049 - val_mse: 1.1049
#
# Epoch 68/200
# 28/28 - 0s - loss: 1.1806 - mse: 1.1806 - val_loss: 1.0406 - val_mse: 1.0406
#
# Epoch 69/200
# 28/28 - 0s - loss: 1.1527 - mse: 1.1527 - val_loss: 1.1850 - val_mse: 1.1850
#
# Epoch 70/200
# 28/28 - 0s - loss: 1.2046 - mse: 1.2046 - val_loss: 0.9860 - val_mse: 0.9860
#
# Epoch 71/200
# 28/28 - 0s - loss: 1.1095 - mse: 1.1095 - val_loss: 0.9859 - val_mse: 0.9859
#
# Epoch 72/200
# 28/28 - 0s - loss: 1.0560 - mse: 1.0560 - val_loss: 1.0215 - val_mse: 1.0215
#
# Epoch 73/200
# 28/28 - 0s - loss: 1.0967 - mse: 1.0967 - val_loss: 0.9875 - val_mse: 0.9875
#
# Epoch 74/200
# 28/28 - 0s - loss: 1.1200 - mse: 1.1200 - val_loss: 0.9841 - val_mse: 0.9841
#
# Epoch 75/200
# 28/28 - 0s - loss: 1.1260 - mse: 1.1260 - val_loss: 1.0371 - val_mse: 1.0371
#
# Epoch 76/200
# 28/28 - 0s - loss: 1.0779 - mse: 1.0779 - val_loss: 1.0654 - val_mse: 1.0654
#
# Epoch 77/200
# 28/28 - 0s - loss: 1.1260 - mse: 1.1260 - val_loss: 0.9743 - val_mse: 0.9743
#
# Epoch 78/200
# 28/28 - 0s - loss: 1.0827 - mse: 1.0827 - val_loss: 1.0008 - val_mse: 1.0008
#
# Epoch 79/200
# 28/28 - 0s - loss: 1.0703 - mse: 1.0703 - val_loss: 0.9783 - val_mse: 0.9783
#
# Epoch 80/200
# 28/28 - 0s - loss: 1.0949 - mse: 1.0949 - val_loss: 0.9995 - val_mse: 0.9995
#
# Epoch 81/200
# 28/28 - 0s - loss: 1.1207 - mse: 1.1207 - val_loss: 0.9878 - val_mse: 0.9878
#
# Epoch 82/200
# 28/28 - 0s - loss: 1.1494 - mse: 1.1494 - val_loss: 1.0653 - val_mse: 1.0653
#
# Epoch 83/200
# 28/28 - 0s - loss: 1.1115 - mse: 1.1115 - val_loss: 1.0023 - val_mse: 1.0023
#
# Epoch 84/200
# 28/28 - 0s - loss: 1.1299 - mse: 1.1299 - val_loss: 1.0097 - val_mse: 1.0097
#
# Epoch 85/200
# 28/28 - 0s - loss: 1.0941 - mse: 1.0941 - val_loss: 1.0812 - val_mse: 1.0812
#
# Epoch 86/200
# 28/28 - 0s - loss: 1.0793 - mse: 1.0793 - val_loss: 0.9753 - val_mse: 0.9753
#
# Epoch 87/200
# 28/28 - 0s - loss: 1.1343 - mse: 1.1343 - val_loss: 1.1742 - val_mse: 1.1742
#
# Epoch 88/200
# 28/28 - 0s - loss: 1.1050 - mse: 1.1050 - val_loss: 1.1297 - val_mse: 1.1297
#
# Epoch 89/200
# 28/28 - 0s - loss: 1.0764 - mse: 1.0764 - val_loss: 1.0328 - val_mse: 1.0328
#
# Epoch 90/200
# 28/28 - 0s - loss: 1.1019 - mse: 1.1019 - val_loss: 0.9809 - val_mse: 0.9809
#
# Epoch 91/200
# 28/28 - 0s - loss: 1.0919 - mse: 1.0919 - val_loss: 1.0575 - val_mse: 1.0575
#
# Epoch 92/200
# 28/28 - 0s - loss: 1.0630 - mse: 1.0630 - val_loss: 1.0470 - val_mse: 1.0470
#
# Epoch 93/200
# 28/28 - 0s - loss: 1.0444 - mse: 1.0444 - val_loss: 1.0310 - val_mse: 1.0310
#
# Epoch 94/200
# 28/28 - 0s - loss: 1.1350 - mse: 1.1350 - val_loss: 0.9925 - val_mse: 0.9925
#
# Epoch 95/200
# 28/28 - 0s - loss: 1.0590 - mse: 1.0590 - val_loss: 1.0301 - val_mse: 1.0301
#
# Epoch 96/200
# 28/28 - 0s - loss: 1.0622 - mse: 1.0622 - val_loss: 1.0063 - val_mse: 1.0063
#
# Epoch 97/200
# 28/28 - 0s - loss: 1.0665 - mse: 1.0665 - val_loss: 1.0274 - val_mse: 1.0274
#
# Epoch 98/200
# 28/28 - 0s - loss: 1.0738 - mse: 1.0738 - val_loss: 1.1314 - val_mse: 1.1314
#
# Epoch 99/200
# 28/28 - 0s - loss: 1.1430 - mse: 1.1430 - val_loss: 0.9942 - val_mse: 0.9942
#
# Epoch 100/200
# 28/28 - 0s - loss: 1.1310 - mse: 1.1310 - val_loss: 1.0269 - val_mse: 1.0269
#
# Epoch 101/200
# 28/28 - 0s - loss: 1.1480 - mse: 1.1480 - val_loss: 0.9844 - val_mse: 0.9844
#
# Epoch 102/200
# 28/28 - 0s - loss: 1.0514 - mse: 1.0514 - val_loss: 0.9798 - val_mse: 0.9798
#
# Epoch 103/200
# 28/28 - 0s - loss: 1.0915 - mse: 1.0915 - val_loss: 0.9735 - val_mse: 0.9735
#
# Epoch 104/200
# 28/28 - 0s - loss: 1.0360 - mse: 1.0360 - val_loss: 1.1169 - val_mse: 1.1169
#
# Epoch 105/200
# 28/28 - 0s - loss: 1.0998 - mse: 1.0998 - val_loss: 0.9675 - val_mse: 0.9675
#
# Epoch 106/200
# 28/28 - 0s - loss: 1.0592 - mse: 1.0592 - val_loss: 1.0414 - val_mse: 1.0414
#
# Epoch 107/200
# 28/28 - 0s - loss: 1.1229 - mse: 1.1229 - val_loss: 0.9839 - val_mse: 0.9839
#
# Epoch 108/200
# 28/28 - 0s - loss: 1.1021 - mse: 1.1021 - val_loss: 1.0318 - val_mse: 1.0318
#
# Epoch 109/200
# 28/28 - 0s - loss: 1.1159 - mse: 1.1159 - val_loss: 1.0000 - val_mse: 1.0000
#
# Epoch 110/200
# 28/28 - 0s - loss: 1.1100 - mse: 1.1100 - val_loss: 0.9744 - val_mse: 0.9744
#
# Epoch 111/200
# 28/28 - 0s - loss: 1.0443 - mse: 1.0443 - val_loss: 0.9693 - val_mse: 0.9693
#
# Epoch 112/200
# 28/28 - 0s - loss: 1.1485 - mse: 1.1485 - val_loss: 1.0529 - val_mse: 1.0529
#
# Epoch 113/200
# 28/28 - 0s - loss: 1.1305 - mse: 1.1305 - val_loss: 1.3694 - val_mse: 1.3694
#
# Epoch 114/200
# 28/28 - 0s - loss: 1.1928 - mse: 1.1928 - val_loss: 1.0130 - val_mse: 1.0130
#
# Epoch 115/200
# 28/28 - 0s - loss: 1.0649 - mse: 1.0649 - val_loss: 1.0888 - val_mse: 1.0888
# Epoch 116/200
# 28/28 - 0s - loss: 1.0965 - mse: 1.0965 - val_loss: 1.0201 - val_mse: 1.0201
#
# Epoch 117/200
# 28/28 - 0s - loss: 1.1799 - mse: 1.1799 - val_loss: 0.9766 - val_mse: 0.9766
#
# Epoch 118/200
# 28/28 - 0s - loss: 1.1140 - mse: 1.1140 - val_loss: 1.0891 - val_mse: 1.0891
#
# Epoch 119/200
# 28/28 - 0s - loss: 1.1041 - mse: 1.1041 - val_loss: 0.9768 - val_mse: 0.9768
#
# Epoch 120/200
# 28/28 - 0s - loss: 1.1280 - mse: 1.1280 - val_loss: 0.9737 - val_mse: 0.9737
#
# Epoch 121/200
# 28/28 - 0s - loss: 1.1091 - mse: 1.1091 - val_loss: 1.0216 - val_mse: 1.0216
#
# Epoch 122/200
# 28/28 - 0s - loss: 1.0778 - mse: 1.0778 - val_loss: 1.0478 - val_mse: 1.0478
#
# Epoch 123/200
# 28/28 - 0s - loss: 1.0638 - mse: 1.0638 - val_loss: 1.0287 - val_mse: 1.0287
#
# Epoch 124/200
# 28/28 - 0s - loss: 1.1393 - mse: 1.1393 - val_loss: 0.9580 - val_mse: 0.9580
#
# Epoch 125/200
# 28/28 - 0s - loss: 1.1456 - mse: 1.1456 - val_loss: 1.1022 - val_mse: 1.1022
#
# Epoch 126/200
# 28/28 - 0s - loss: 1.1240 - mse: 1.1240 - val_loss: 1.1722 - val_mse: 1.1722
#
# Epoch 127/200
# 28/28 - 0s - loss: 1.1144 - mse: 1.1144 - val_loss: 1.0639 - val_mse: 1.0639
#
# Epoch 128/200
# 28/28 - 0s - loss: 1.1291 - mse: 1.1291 - val_loss: 0.9935 - val_mse: 0.9935
#
# Epoch 129/200
# 28/28 - 0s - loss: 1.1200 - mse: 1.1200 - val_loss: 1.1675 - val_mse: 1.1675
#
# Epoch 130/200
# 28/28 - 0s - loss: 1.0898 - mse: 1.0898 - val_loss: 1.0512 - val_mse: 1.0512
#
# Epoch 131/200
# 28/28 - 0s - loss: 1.0865 - mse: 1.0865 - val_loss: 0.9736 - val_mse: 0.9736
#
# Epoch 132/200
# 28/28 - 0s - loss: 1.1611 - mse: 1.1611 - val_loss: 0.9655 - val_mse: 0.9655
#
# Epoch 133/200
# 28/28 - 0s - loss: 1.1060 - mse: 1.1060 - val_loss: 0.9723 - val_mse: 0.9723
#
# Epoch 134/200
# 28/28 - 0s - loss: 1.0903 - mse: 1.0903 - val_loss: 0.9627 - val_mse: 0.9627
#
# Epoch 135/200
# 28/28 - 0s - loss: 1.1339 - mse: 1.1339 - val_loss: 0.9871 - val_mse: 0.9871
#
# Epoch 136/200
# 28/28 - 0s - loss: 1.0834 - mse: 1.0834 - val_loss: 1.1390 - val_mse: 1.1390
#
# Epoch 137/200
# 28/28 - 0s - loss: 1.0528 - mse: 1.0528 - val_loss: 0.9671 - val_mse: 0.9671
#
# Epoch 138/200
# 28/28 - 0s - loss: 1.1603 - mse: 1.1603 - val_loss: 1.1099 - val_mse: 1.1099
#
# Epoch 139/200
# 28/28 - 0s - loss: 1.1026 - mse: 1.1026 - val_loss: 0.9868 - val_mse: 0.9868
#
# Epoch 140/200
# 28/28 - 0s - loss: 1.1284 - mse: 1.1284 - val_loss: 0.9563 - val_mse: 0.9563
#
# Epoch 141/200
# 28/28 - 0s - loss: 1.0971 - mse: 1.0971 - val_loss: 0.9599 - val_mse: 0.9599
#
# Epoch 142/200
# 28/28 - 0s - loss: 1.0778 - mse: 1.0778 - val_loss: 0.9624 - val_mse: 0.9624
#
# Epoch 143/200
# 28/28 - 0s - loss: 1.0815 - mse: 1.0815 - val_loss: 1.0964 - val_mse: 1.0964
#
# Epoch 144/200
# 28/28 - 0s - loss: 1.1918 - mse: 1.1918 - val_loss: 0.9590 - val_mse: 0.9590
#
# Epoch 145/200
# 28/28 - 0s - loss: 1.1013 - mse: 1.1013 - val_loss: 0.9610 - val_mse: 0.9610
#
# Epoch 146/200
# 28/28 - 0s - loss: 1.0348 - mse: 1.0348 - val_loss: 1.3441 - val_mse: 1.3441
#
# Epoch 147/200
# 28/28 - 0s - loss: 1.0676 - mse: 1.0676 - val_loss: 0.9885 - val_mse: 0.9885
#
# Epoch 148/200
# 28/28 - 0s - loss: 1.0360 - mse: 1.0360 - val_loss: 0.9616 - val_mse: 0.9616
#
# Epoch 149/200
# 28/28 - 0s - loss: 1.1091 - mse: 1.1091 - val_loss: 1.0045 - val_mse: 1.0045
#
# Epoch 150/200
# 28/28 - 0s - loss: 1.1547 - mse: 1.1547 - val_loss: 1.0137 - val_mse: 1.0137
#
# Epoch 151/200
# 28/28 - 0s - loss: 1.0806 - mse: 1.0806 - val_loss: 0.9859 - val_mse: 0.9859
#
# Epoch 152/200
# 28/28 - 0s - loss: 1.1003 - mse: 1.1003 - val_loss: 1.1253 - val_mse: 1.1253
#
# Epoch 153/200
# 28/28 - 0s - loss: 1.0966 - mse: 1.0966 - val_loss: 0.9741 - val_mse: 0.9741
#
# Epoch 154/200
# 28/28 - 0s - loss: 1.1241 - mse: 1.1241 - val_loss: 1.0350 - val_mse: 1.0350
#
# Epoch 155/200
# 28/28 - 0s - loss: 1.1095 - mse: 1.1095 - val_loss: 1.0191 - val_mse: 1.0191
#
# Epoch 156/200
# 28/28 - 0s - loss: 1.1114 - mse: 1.1114 - val_loss: 1.0357 - val_mse: 1.0357
#
# Epoch 157/200
# 28/28 - 0s - loss: 1.0836 - mse: 1.0836 - val_loss: 0.9660 - val_mse: 0.9660
#
# Epoch 158/200
# 28/28 - 0s - loss: 1.1465 - mse: 1.1465 - val_loss: 0.9641 - val_mse: 0.9641
#
# Epoch 159/200
# 28/28 - 0s - loss: 1.1304 - mse: 1.1304 - val_loss: 0.9633 - val_mse: 0.9633
#
# Epoch 160/200
# 28/28 - 0s - loss: 1.0495 - mse: 1.0495 - val_loss: 0.9690 - val_mse: 0.9690
#
# Epoch 161/200
# 28/28 - 0s - loss: 1.1204 - mse: 1.1204 - val_loss: 0.9735 - val_mse: 0.9735
#
# Epoch 162/200
# 28/28 - 0s - loss: 1.0984 - mse: 1.0984 - val_loss: 0.9907 - val_mse: 0.9907
#
# Epoch 163/200
# 28/28 - 0s - loss: 1.1099 - mse: 1.1099 - val_loss: 1.0558 - val_mse: 1.0558
#
# Epoch 164/200
# 28/28 - 0s - loss: 1.1150 - mse: 1.1150 - val_loss: 1.0413 - val_mse: 1.0413
#
# Epoch 165/200
# 28/28 - 0s - loss: 1.1354 - mse: 1.1354 - val_loss: 0.9733 - val_mse: 0.9733
#
# Epoch 166/200
# 28/28 - 0s - loss: 1.1323 - mse: 1.1323 - val_loss: 0.9633 - val_mse: 0.9633
#
# Epoch 167/200
# 28/28 - 0s - loss: 1.1224 - mse: 1.1224 - val_loss: 0.9793 - val_mse: 0.9793
#
# Epoch 168/200
# 28/28 - 0s - loss: 1.1220 - mse: 1.1220 - val_loss: 0.9581 - val_mse: 0.9581
#
# Epoch 169/200
# 28/28 - 0s - loss: 1.1089 - mse: 1.1089 - val_loss: 0.9983 - val_mse: 0.9983
#
# Epoch 170/200
# 28/28 - 0s - loss: 1.0966 - mse: 1.0966 - val_loss: 1.0152 - val_mse: 1.0152
#
# Epoch 171/200
# 28/28 - 0s - loss: 0.9950 - mse: 0.9950 - val_loss: 1.1375 - val_mse: 1.1375
#
# Epoch 172/200
# 28/28 - 0s - loss: 1.0870 - mse: 1.0870 - val_loss: 0.9506 - val_mse: 0.9506
#
# Epoch 173/200
# 28/28 - 0s - loss: 1.1144 - mse: 1.1144 - val_loss: 0.9574 - val_mse: 0.9574
#
# Epoch 174/200
# 28/28 - 0s - loss: 1.0737 - mse: 1.0737 - val_loss: 0.9690 - val_mse: 0.9690
#
# Epoch 175/200
# 28/28 - 0s - loss: 1.0603 - mse: 1.0603 - val_loss: 0.9764 - val_mse: 0.9764
#
# Epoch 176/200
# 28/28 - 0s - loss: 1.0324 - mse: 1.0324 - val_loss: 0.9532 - val_mse: 0.9532
#
# Epoch 177/200
# 28/28 - 0s - loss: 1.1047 - mse: 1.1047 - val_loss: 0.9566 - val_mse: 0.9566
#
# Epoch 178/200
# 28/28 - 0s - loss: 1.0869 - mse: 1.0869 - val_loss: 0.9532 - val_mse: 0.9532
#
# Epoch 179/200
# 28/28 - 0s - loss: 1.0311 - mse: 1.0311 - val_loss: 0.9832 - val_mse: 0.9832
#
# Epoch 180/200
# 28/28 - 0s - loss: 1.0861 - mse: 1.0861 - val_loss: 1.3295 - val_mse: 1.3295
#
# Epoch 181/200
# 28/28 - 0s - loss: 1.0215 - mse: 1.0215 - val_loss: 0.9827 - val_mse: 0.9827
#
# ...
#
# Epoch 72/100
# 3/3 - 0s - loss: 0.1969 - mse: 0.1969 - val_loss: 0.1765 - val_mse: 0.1765
#
# Epoch 73/100
# 3/3 - 0s - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1751 - val_mse: 0.1751
#
# Epoch 74/100
# 3/3 - 0s - loss: 0.1990 - mse: 0.1990 - val_loss: 0.1730 - val_mse: 0.1730
#
# Epoch 75/100
# 3/3 - 0s - loss: 0.1934 - mse: 0.1934 - val_loss: 0.1717 - val_mse: 0.1717
#
# Epoch 76/100
# 3/3 - 0s - loss: 0.1937 - mse: 0.1937 - val_loss: 0.1700 - val_mse: 0.1700
#
# Epoch 77/100
# 3/3 - 0s - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1689 - val_mse: 0.1689
#
# Epoch 78/100
# 3/3 - 0s - loss: 0.1905 - mse: 0.1905 - val_loss: 0.1678 - val_mse: 0.1678
#
# Epoch 79/100
# 3/3 - 0s - loss: 0.1887 - mse: 0.1887 - val_loss: 0.1665 - val_mse: 0.1665
#
# Epoch 80/100
# 3/3 - 0s - loss: 0.1903 - mse: 0.1903 - val_loss: 0.1655 - val_mse: 0.1655
#
# Epoch 81/100
# 3/3 - 0s - loss: 0.1814 - mse: 0.1814 - val_loss: 0.1644 - val_mse: 0.1644
#
# Epoch 82/100
# 3/3 - 0s - loss: 0.1858 - mse: 0.1858 - val_loss: 0.1635 - val_mse: 0.1635
#
# Epoch 83/100
# 3/3 - 0s - loss: 0.1923 - mse: 0.1923 - val_loss: 0.1624 - val_mse: 0.1624
#
# Epoch 84/100
# 3/3 - 0s - loss: 0.1849 - mse: 0.1849 - val_loss: 0.1616 - val_mse: 0.1616
#
# Epoch 85/100
# 3/3 - 0s - loss: 0.1812 - mse: 0.1812 - val_loss: 0.1605 - val_mse: 0.1605
#
# Epoch 86/100
# 3/3 - 0s - loss: 0.1832 - mse: 0.1832 - val_loss: 0.1588 - val_mse: 0.1588
#
# Epoch 87/100
# 3/3 - 0s - loss: 0.1811 - mse: 0.1811 - val_loss: 0.1575 - val_mse: 0.1575
#
# Epoch 88/100
# 3/3 - 0s - loss: 0.1776 - mse: 0.1776 - val_loss: 0.1556 - val_mse: 0.1556
#
# Epoch 89/100
# 3/3 - 0s - loss: 0.1837 - mse: 0.1837 - val_loss: 0.1538 - val_mse: 0.1538
#
# Epoch 90/100
# 3/3 - 0s - loss: 0.1804 - mse: 0.1804 - val_loss: 0.1527 - val_mse: 0.1527
#
# Epoch 91/100
# 3/3 - 0s - loss: 0.1762 - mse: 0.1762 - val_loss: 0.1512 - val_mse: 0.1512
#
# Epoch 92/100
# 3/3 - 0s - loss: 0.1750 - mse: 0.1750 - val_loss: 0.1504 - val_mse: 0.1504
#
# Epoch 93/100
# 3/3 - 0s - loss: 0.1731 - mse: 0.1731 - val_loss: 0.1502 - val_mse: 0.1502
#
# Epoch 94/100
# 3/3 - 0s - loss: 0.1699 - mse: 0.1699 - val_loss: 0.1501 - val_mse: 0.1501
#
# Epoch 95/100
# 3/3 - 0s - loss: 0.1592 - mse: 0.1592 - val_loss: 0.1493 - val_mse: 0.1493
#
# Epoch 96/100
# 3/3 - 0s - loss: 0.1652 - mse: 0.1652 - val_loss: 0.1486 - val_mse: 0.1486
#
# Epoch 97/100
# 3/3 - 0s - loss: 0.1695 - mse: 0.1695 - val_loss: 0.1477 - val_mse: 0.1477
#
# Epoch 98/100
# 3/3 - 0s - loss: 0.1716 - mse: 0.1716 - val_loss: 0.1467 - val_mse: 0.1467
#
# Epoch 99/100
# 3/3 - 0s - loss: 0.1615 - mse: 0.1615 - val_loss: 0.1456 - val_mse: 0.1456
#
# Epoch 100/100
# 3/3 - 0s - loss: 0.1636 - mse: 0.1636 - val_loss: 0.1447 - val_mse: 0.1447
#
# Test accuracy:
# 0.14471077919006348
# 100%|███████████████████████████████████████████████| 10/10 [03:43<00:00, 22.36s/trial, best loss: 0.07587600499391556]
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.0005414485931396, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A20EC52DF0>}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [0], 'Dropout': [0], 'batch_size': [0], 'epochs': [0], 'optimizer': [0]}, 'vals': {'Activation': [1], 'Dropout': [0.692539034315719], 'batch_size': [0], 'epochs': [1], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 0, 23, 46000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 0, 43, 356000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 0.08853523433208466, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A20C07B4C0>}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [1], 'Dropout': [1], 'batch_size': [1], 'epochs': [1], 'optimizer': [1]}, 'vals': {'Activation': [2], 'Dropout': [0.8366666847115819], 'batch_size': [0], 'epochs': [1], 'optimizer': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 0, 43, 359000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 1, 5, 933000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 0.41866183280944824, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A20F11E250>}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [2], 'Dropout': [2], 'batch_size': [2], 'epochs': [2], 'optimizer': [2]}, 'vals': {'Activation': [1], 'Dropout': [0.7275581656084844], 'batch_size': [2], 'epochs': [2], 'optimizer': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 1, 5, 938000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 1, 26, 152000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 0.07587600499391556, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A21B0FAF40>}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [3], 'Dropout': [3], 'batch_size': [3], 'epochs': [3], 'optimizer': [3]}, 'vals': {'Activation': [2], 'Dropout': [0.7646166765488501], 'batch_size': [2], 'epochs': [1], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 1, 26, 156000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 1, 40, 955000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 0.4155445098876953, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A21F13C640>}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [4], 'Dropout': [4], 'batch_size': [4], 'epochs': [4], 'optimizer': [4]}, 'vals': {'Activation': [3], 'Dropout': [0.2330896882313117], 'batch_size': [3], 'epochs': [4], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 1, 40, 959000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 2, 9, 701000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 0.2388761341571808, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A2238BB4C0>}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [5], 'Dropout': [5], 'batch_size': [5], 'epochs': [5], 'optimizer': [5]}, 'vals': {'Activation': [0], 'Dropout': [0.6883693507416478], 'batch_size': [2], 'epochs': [2], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 2, 9, 705000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 2, 29, 562000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 0.22149762511253357, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A219C75C40>}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [6], 'Dropout': [6], 'batch_size': [6], 'epochs': [6], 'optimizer': [6]}, 'vals': {'Activation': [2], 'Dropout': [0.39730440328653105], 'batch_size': [0], 'epochs': [3], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 2, 29, 570000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 3, 10, 497000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 0.15252377092838287, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A22AAAEF10>}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [7], 'Dropout': [7], 'batch_size': [7], 'epochs': [7], 'optimizer': [7]}, 'vals': {'Activation': [0], 'Dropout': [0.258985915829989], 'batch_size': [1], 'epochs': [3], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 3, 10, 502000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 3, 39, 349000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 0.402096688747406, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A21B1D75E0>}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [8], 'Dropout': [8], 'batch_size': [8], 'epochs': [8], 'optimizer': [8]}, 'vals': {'Activation': [3], 'Dropout': [0.06528675004895668], 'batch_size': [2], 'epochs': [2], 'optimizer': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 3, 39, 354000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 3, 58, 535000)}
# {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': 0.14471077919006348, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001A2322889A0>}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [9], 'Dropout': [9], 'batch_size': [9], 'epochs': [9], 'optimizer': [9]}, 'vals': {'Activation': [0], 'Dropout': [0.20946774700477522], 'batch_size': [3], 'epochs': [0], 'optimizer': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 9, 3, 58, 539000), 'refresh_time': datetime.datetime(2021, 1, 15, 9, 4, 6, 623000)}
# Evalutation of best performing model:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b42494599255> in <module>
#      95     X_train, y_train, X_test, y_test = data()
#      96     print("Evalutation of best performing model:")
# ---> 97     print(best_model.evaluate(X_test, y_test))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1352       else:
#    1353         # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1354         data_handler = data_adapter.DataHandler(
#    1355             x=x,
#    1356             y=y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1098
#    1099     adapter_cls = select_data_adapter(x, y)
# -> 1100     self._adapter = adapter_cls(
#    1101         x,
#    1102         y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     272
#     273     num_samples = set(int(i.shape[0]) for i in nest.flatten(inputs)).pop()
# --> 274     _check_data_cardinality(inputs)
#     275
#     276     # If batch_size is not passed but steps is, calculate from the input data.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _check_data_cardinality(data)
#    1527           label, ", ".join(str(i.shape[0]) for i in nest.flatten(single_data)))
#    1528     msg += "Make sure all arrays contain the same number of samples."
# -> 1529     raise ValueError(msg)
#    1530
#    1531
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 331
#   y sizes: 110
# Make sure all arrays contain the same number of samples.
