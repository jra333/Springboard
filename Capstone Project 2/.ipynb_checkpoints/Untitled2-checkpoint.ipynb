# %%
from __future__ import print_function
import numpy as np

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform
from keras.preprocessing import sequence
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint


from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler



def data():
    
    maxlen = 352
    max_features = 6
    
    dataset = read_csv('data/test.csv', index_col='Date')
    X = dataset.drop(labels=['close', 'close_nextday'], axis=1)
    y = dataset['close_nextday']

    values_x = X.values
    values_y = y.values
    values_y = values_y.reshape(-1, 1)

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data_X = scaler.fit_transform(values_x)
    scaled_data_y = scaler.fit_transform(values_y)

    X_train = scaled_data_X[:int(X.shape[0] * 0.8)]
    X_test = scaled_data_X[int(y.shape[0] * 0.8):]
    y_train = scaled_data_y[:int(X.shape[0] * 0.8)]
    y_test = scaled_data_y[int(y.shape[0] * 0.8):]

    X_train = np.array(X_train)
    X_test = np.array(X_test)
    print(len(X_train), 'train sequences')
    print(len(X_test), 'test sequences')
    
    print("Pad sequences (samples x time)")
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    print('X_train shape:', X_train.shape)
    print('X_test shape:', X_test.shape)
    

    return X_train, X_test, y_train, y_test, max_features, maxlen

def model(X_train, X_test, y_train, y_test, max_features, maxlen):
    
    model = Sequential()
    model.add(Embedding(max_features, 128, input_length=maxlen))
    model.add(LSTM(128))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=4)
    checkpointer = ModelCheckpoint(filepath='keras_weights.hdf5',
                                   verbose=1,
                                   save_best_only=True)

    model.fit(X_train, y_train,
              batch_size={{choice([32, 64, 128])}},
              epochs=1,
              validation_split=0.8,
              callbacks=[early_stopping, checkpointer])

    score, acc = model.evaluate(X_test, y_test, verbose=0)

    print('Test accuracy:', acc)
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}



if __name__ == '__main__':
    best_run, best_model = optim.minimize(model=model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=10,
                                          trials=Trials(),
                                          notebook_name='Untitled2')
print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.preprocessing import sequence
# except:
#     pass
#
# try:
#     from keras.datasets import imdb
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.layers.embeddings import Embedding
# except:
#     pass
#
# try:
#     from keras.layers.recurrent import LSTM
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'batch_size': hp.choice('batch_size', [32, 64, 128]),
#     }
#
# >>> Data
#   1:
#   2:
#   3: maxlen = 352
#   4: max_features = 6
#   5:
#   6: dataset = read_csv('data/test.csv', index_col='Date')
#   7: X = dataset.drop(labels=['close', 'close_nextday'], axis=1)
#   8: y = dataset['close_nextday']
#   9:
#  10: values_x = X.values
#  11: values_y = y.values
#  12: values_y = values_y.reshape(-1, 1)
#  13:
#  14: scaler = MinMaxScaler(feature_range=(0, 1))
#  15: scaled_data_X = scaler.fit_transform(values_x)
#  16: scaled_data_y = scaler.fit_transform(values_y)
#  17:
#  18: X_train = scaled_data_X[:int(X.shape[0] * 0.8)]
#  19: X_test = scaled_data_X[int(y.shape[0] * 0.8):]
#  20: y_train = scaled_data_y[:int(X.shape[0] * 0.8)]
#  21: y_test = scaled_data_y[int(y.shape[0] * 0.8):]
#  22:
#  23: X_train = np.array(X_train)
#  24: X_test = np.array(X_test)
#  25: print(len(X_train), 'train sequences')
#  26: print(len(X_test), 'test sequences')
#  27:
#  28: print("Pad sequences (samples x time)")
#  29: y_train = np.array(y_train)
#  30: y_test = np.array(y_test)
#  31: print('X_train shape:', X_train.shape)
#  32: print('X_test shape:', X_test.shape)
#  33:
#  34:
#  35:
#  36:
#  37:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:
#   4:     model = Sequential()
#   5:     model.add(Embedding(max_features, 128, input_length=maxlen))
#   6:     model.add(LSTM(128))
#   7:     model.add(Dropout(space['Dropout']))
#   8:     model.add(Dense(1))
#   9:     model.add(Activation('sigmoid'))
#  10:
#  11:     model.compile(loss='binary_crossentropy',
#  12:                   optimizer='adam',
#  13:                   metrics=['accuracy'])
#  14:
#  15:     early_stopping = EarlyStopping(monitor='val_loss', patience=4)
#  16:     checkpointer = ModelCheckpoint(filepath='keras_weights.hdf5',
#  17:                                    verbose=1,
#  18:                                    save_best_only=True)
#  19:
#  20:     model.fit(X_train, y_train,
#  21:               batch_size=space['batch_size'],
#  22:               epochs=1,
#  23:               validation_split=0.8,
#  24:               callbacks=[early_stopping, checkpointer])
#  25:
#  26:     score, acc = model.evaluate(X_test, y_test, verbose=0)
#  27:
#  28:     print('Test accuracy:', acc)
#  29:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#  30:
# 352 train sequences
# 89 test sequences
# Pad sequences (samples x time)
# X_train shape: (352, 6)
# X_test shape: (89, 6)
#   0%|                                                                           | 0/10 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 6).
# 1/1 [==============================]
#  - ETA: 0s - loss: 0.6958 - accuracy: 0.0000e+00
#   0%|                                                                           | 0/10 [00:03<?, ?trial/s, best loss=?]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 1/1 [==============================]
#  - 5s 5s/step - loss: 0.6958 - accuracy: 0.0000e+00 - val_loss: 0.6851 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.68509, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  10%|██████▎                                                        | 1/10 [00:05<00:51,  5.72s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_1_input'), name='embedding_1_input', description="created by layer 'embedding_1_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_1_input'), name='embedding_1_input', description="created by layer 'embedding_1_input'"), but it was called on an input with incompatible shape (None, 6).
# 1/3 [=========>....................]
#  - ETA: 4s - loss: 0.6915 - accuracy: 0.0000e+00
#
# 3/3 [==============================]
#  - ETA: 0s - loss: 0.6884 - accuracy: 0.0000e+00
#  10%|██████▎                                                        | 1/10 [00:08<00:51,  5.72s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_1_input'), name='embedding_1_input', description="created by layer 'embedding_1_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 3/3 [==============================]
#  - 3s 336ms/step - loss: 0.6879 - accuracy: 0.0000e+00 - val_loss: 0.6614 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.66135, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  20%|████████████▌                                                  | 2/10 [00:09<00:40,  5.07s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_2_input'), name='embedding_2_input', description="created by layer 'embedding_2_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_2_input'), name='embedding_2_input', description="created by layer 'embedding_2_input'"), but it was called on an input with incompatible shape (None, 6).
# 1/2 [==============>...............]
#  - ETA: 2s - loss: 0.6938 - accuracy: 0.0000e+00
#  20%|████████████▌                                                  | 2/10 [00:12<00:40,  5.07s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_2_input'), name='embedding_2_input', description="created by layer 'embedding_2_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 2/2 [==============================]
#  - 3s 582ms/step - loss: 0.6934 - accuracy: 0.0000e+00 - val_loss: 0.6769 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.67686, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  30%|██████████████████▉                                            | 3/10 [00:12<00:32,  4.61s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_3_input'), name='embedding_3_input', description="created by layer 'embedding_3_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_3_input'), name='embedding_3_input', description="created by layer 'embedding_3_input'"), but it was called on an input with incompatible shape (None, 6).
# 1/2 [==============>...............]
#  - ETA: 2s - loss: 0.6897 - accuracy: 0.0000e+00
#  30%|██████████████████▉                                            | 3/10 [00:15<00:32,  4.61s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_3_input'), name='embedding_3_input', description="created by layer 'embedding_3_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 2/2 [==============================]
#  - 3s 586ms/step - loss: 0.6891 - accuracy: 0.0000e+00 - val_loss: 0.6699 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.66988, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  40%|█████████████████████████▏                                     | 4/10 [00:16<00:25,  4.28s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_4_input'), name='embedding_4_input', description="created by layer 'embedding_4_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_4_input'), name='embedding_4_input', description="created by layer 'embedding_4_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_train_function.<locals>.train_function at 0x000002987CA703A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 [=========>....................]
#  - ETA: 4s - loss: 0.6873 - accuracy: 0.0000e+00
#  40%|█████████████████████████▏                                     | 4/10 [00:19<00:25,  4.28s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_4_input'), name='embedding_4_input', description="created by layer 'embedding_4_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 3/3 [==============================]
#  - 3s 318ms/step - loss: 0.6843 - accuracy: 0.0000e+00 - val_loss: 0.6620 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.66200, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  50%|███████████████████████████████▌                               | 5/10 [00:19<00:20,  4.07s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_5_input'), name='embedding_5_input', description="created by layer 'embedding_5_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_5_input'), name='embedding_5_input', description="created by layer 'embedding_5_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x000002987FB349D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================]
#  - ETA: 0s - loss: 0.6942 - accuracy: 0.0000e+00
#  50%|███████████████████████████████▌                               | 5/10 [00:22<00:20,  4.07s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_5_input'), name='embedding_5_input', description="created by layer 'embedding_5_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 1/1 [==============================]
#  - 3s 3s/step - loss: 0.6942 - accuracy: 0.0000e+00 - val_loss: 0.6830 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.68302, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  60%|█████████████████████████████████████▊                         | 6/10 [00:23<00:15,  3.81s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_6_input'), name='embedding_6_input', description="created by layer 'embedding_6_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_6_input'), name='embedding_6_input', description="created by layer 'embedding_6_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_train_function.<locals>.train_function at 0x000002980419C550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 [=========>....................]
#  - ETA: 5s - loss: 0.6960 - accuracy: 0.0000e+00
#  60%|█████████████████████████████████████▊                         | 6/10 [00:25<00:15,  3.81s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_6_input'), name='embedding_6_input', description="created by layer 'embedding_6_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 3/3 [==============================]
#  - 3s 306ms/step - loss: 0.6921 - accuracy: 0.0000e+00 - val_loss: 0.6663 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.66629, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  70%|████████████████████████████████████████████                   | 7/10 [00:26<00:11,  3.76s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_7_input'), name='embedding_7_input', description="created by layer 'embedding_7_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_7_input'), name='embedding_7_input', description="created by layer 'embedding_7_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_train_function.<locals>.train_function at 0x0000029808343820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================]
#  - ETA: 0s - loss: 0.6917 - accuracy: 0.0000e+00
#  70%|████████████████████████████████████████████                   | 7/10 [00:29<00:11,  3.76s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_7_input'), name='embedding_7_input', description="created by layer 'embedding_7_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 1/1 [==============================]
#  - 3s 3s/step - loss: 0.6917 - accuracy: 0.0000e+00 - val_loss: 0.6803 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.68034, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  80%|██████████████████████████████████████████████████▍            | 8/10 [00:30<00:07,  3.61s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_8_input'), name='embedding_8_input', description="created by layer 'embedding_8_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_8_input'), name='embedding_8_input', description="created by layer 'embedding_8_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x0000029808343160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 [=========>....................]
#  - ETA: 4s - loss: 0.6965 - accuracy: 0.0000e+00
#  80%|██████████████████████████████████████████████████▍            | 8/10 [00:32<00:07,  3.61s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_8_input'), name='embedding_8_input', description="created by layer 'embedding_8_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 3/3 [==============================]
#  - 3s 315ms/step - loss: 0.6923 - accuracy: 0.0000e+00 - val_loss: 0.6652 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.66516, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
#  90%|████████████████████████████████████████████████████████▋      | 9/10 [00:33<00:03,  3.64s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_9_input'), name='embedding_9_input', description="created by layer 'embedding_9_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_9_input'), name='embedding_9_input', description="created by layer 'embedding_9_input'"), but it was called on an input with incompatible shape (None, 6).
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_train_function.<locals>.train_function at 0x000002980FE00310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 [==============>...............]
#  - ETA: 2s - loss: 0.6982 - accuracy: 0.0000e+00
#  90%|████████████████████████████████████████████████████████▋      | 9/10 [00:36<00:03,  3.64s/trial, best loss: -0.0]WARNING:tensorflow:Model was constructed with shape (None, 352) for input KerasTensor(type_spec=TensorSpec(shape=(None, 352), dtype=tf.float32, name='embedding_9_input'), name='embedding_9_input', description="created by layer 'embedding_9_input'"), but it was called on an input with incompatible shape (None, 6).
#
# 2/2 [==============================]
#  - 3s 624ms/step - loss: 0.6977 - accuracy: 0.0000e+00 - val_loss: 0.6779 - val_accuracy: 0.0035
#
#
# Epoch 00001: val_loss improved from inf to 0.67788, saving model to keras_weights.hdf5
# Test accuracy:
# 0.0
# 100%|██████████████████████████████████████████████████████████████| 10/10 [00:37<00:00,  3.71s/trial, best loss: -0.0]
# {'Dropout': 0.21280043312755825, 'batch_size': 2}
