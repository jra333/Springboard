# %%
from __future__ import print_function
import numpy as np

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils

from pandas import read_csv
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler


def data():
    
    dataset = read_csv('data/train.csv', index_col='Date')
    
    X = dataset.drop(labels=['close_nextday', 'close'], axis=1)
    y = dataset['close_nextday']
    
    
    tss = TimeSeriesSplit(n_splits=3)  # n_splits = 3-1...2 splits - 75% train, 25% test

    for train_index, test_index in tss.split(X):
        X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    # Reshape y train, test to match X train, test

    y_train = y_train.values.reshape(-1, 1)
    y_test = y_test.values.reshape(-1, 1)
    
    
    ss = StandardScaler()

    X_train = ss.fit_transform(X_train)
    X_test = ss.fit_transform(X_test)
    y_train = ss.fit_transform(y_train)
    y_test = ss.fit_transform(y_test)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
    y_train = y_train.reshape(y_train.shape[0], 1, 1)
    y_test = y_test.reshape(y_test.shape[0], 1, 1)
    
    return X_train, y_train, X_test, y_test

def model(X_train, y_train, X_test, y_test):

    model = Sequential()
    model.add(LSTM(128))
    model.add(Activation({{choice(['relu', 'sigmoid', 'linear', 'softmax'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))

    model.compile(loss='mse',
                  optimizer={{choice(['rmsprop', 'adam', 'sgd', 'nadam'])}},
                  metrics=['mse'])

    result = model.fit(X_train,
                       y_train,
                       batch_size={{choice([12, 24, 64, 128])}},
                       epochs={{choice([100, 200, 300, 400, 500])}},
                       verbose=2,
                       validation_data=(X_test, y_test))
                       

    score, mse = model.evaluate(X_test, y_test, verbose=0)
    print('Test accuracy:', mse)
    return {'loss': mse, 'status': STATUS_OK, 'model': model}


if __name__ == '__main__':
    trials = Trials()
    best_run, best_model = optim.minimize(model=model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=10,
                                          trials=trials,
                                          notebook_name="LSTM")
    
    for trial in trials:
        print(trial)
    
    X_train, y_train, X_test, y_test = data()
    print("Evalutation of best performing model:")
    print(best_model.evaluate(X_test, y_test))
    print("Best performing model chosen hyper-parameters:")
    print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from keras.preprocessing import sequence
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.layers.embeddings import Embedding
# except:
#     pass
#
# try:
#     from keras.layers.recurrent import LSTM
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# try:
#     from sklearn.model_selection import TimeSeriesSplit
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid', 'linear', 'softmax']),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam', 'sgd', 'nadam']),
#         'batch_size': hp.choice('batch_size', [12, 24, 64, 128]),
#         'epochs': hp.choice('epochs', [100, 200, 300, 400, 500]),
#     }
#
# >>> Data
#   1:
#   2:
#   3: dataset = read_csv('data/train.csv', index_col='Date')
#   4:
#   5: X = dataset.drop(labels=['close_nextday', 'close'], axis=1)
#   6: y = dataset['close_nextday']
#   7:
#   8:
#   9: tss = TimeSeriesSplit(n_splits=3)  # n_splits = 3-1...2 splits - 75% train, 25% test
#  10:
#  11: for train_index, test_index in tss.split(X):
#  12:     X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
#  13:     y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#  14:
#  15: # Reshape y train, test to match X train, test
#  16:
#  17: y_train = y_train.values.reshape(-1, 1)
#  18: y_test = y_test.values.reshape(-1, 1)
#  19:
#  20:
#  21: ss = StandardScaler()
#  22:
#  23: X_train = ss.fit_transform(X_train)
#  24: X_test = ss.fit_transform(X_test)
#  25: y_train = ss.fit_transform(y_train)
#  26: y_test = ss.fit_transform(y_test)
#  27:
#  28: X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
#  29: X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
#  30: y_train = y_train.reshape(y_train.shape[0], 1, 1)
#  31: y_test = y_test.reshape(y_test.shape[0], 1, 1)
#  32:
#  33:
#  34:
#  35:
# >>> Resulting replaced keras model:
#
#   1: def keras_fmin_fnct(space):
#   2:
#   3:
#   4:     model = Sequential()
#   5:     model.add(LSTM(128))
#   6:     model.add(Activation(space['Activation']))
#   7:     model.add(Dropout(space['Dropout']))
#   8:     model.add(Dense(1))
#   9:
#  10:     model.compile(loss='mse',
#  11:                   optimizer=space['optimizer'],
#  12:                   metrics=['mse'])
#  13:
#  14:     result = model.fit(X_train,
#  15:                        y_train,
#  16:                        batch_size=space['batch_size'],
#  17:                        epochs=space['epochs'],
#  18:                        verbose=2,
#  19:                        validation_data=(X_test, y_test))
#  20:
#  21:
#  22:     score, mse = model.evaluate(X_test, y_test, verbose=0)
#  23:     print('Test accuracy:', mse)
#  24:     return {'loss': mse, 'status': STATUS_OK, 'model': model}
#  25:
# Epoch 1/200
# 28/28 - 3s - loss: 1.8883 - mse: 1.8883 - val_loss: 1.0774 - val_mse: 1.0774
#
# Epoch 2/200
# 28/28 - 0s - loss: 1.4507 - mse: 1.4507 - val_loss: 1.2533 - val_mse: 1.2533
#
# Epoch 3/200
# 28/28 - 0s - loss: 1.3341 - mse: 1.3341 - val_loss: 1.2246 - val_mse: 1.2246
#
# Epoch 4/200
# 28/28 - 0s - loss: 1.3090 - mse: 1.3090 - val_loss: 1.0518 - val_mse: 1.0518
#
# Epoch 5/200
# 28/28 - 0s - loss: 1.1252 - mse: 1.1252 - val_loss: 0.9997 - val_mse: 0.9997
#
# Epoch 6/200
# 28/28 - 0s - loss: 1.1029 - mse: 1.1029 - val_loss: 1.0119 - val_mse: 1.0119
#
# Epoch 7/200
# 28/28 - 0s - loss: 1.1769 - mse: 1.1769 - val_loss: 0.9897 - val_mse: 0.9897
#
# Epoch 8/200
# 28/28 - 0s - loss: 1.1711 - mse: 1.1711 - val_loss: 1.1281 - val_mse: 1.1281
#
# Epoch 9/200
# 28/28 - 0s - loss: 1.0645 - mse: 1.0645 - val_loss: 1.1154 - val_mse: 1.1154
#
# Epoch 10/200
# 28/28 - 0s - loss: 1.1324 - mse: 1.1324 - val_loss: 0.9852 - val_mse: 0.9852
#
# Epoch 11/200
# 28/28 - 0s - loss: 1.1521 - mse: 1.1521 - val_loss: 0.9822 - val_mse: 0.9822
#
# Epoch 12/200
# 28/28 - 0s - loss: 1.1237 - mse: 1.1237 - val_loss: 1.0188 - val_mse: 1.0188
#
# Epoch 13/200
# 28/28 - 0s - loss: 1.1640 - mse: 1.1640 - val_loss: 0.9889 - val_mse: 0.9889
#
# Epoch 14/200
# 28/28 - 0s - loss: 1.1198 - mse: 1.1198 - val_loss: 1.0147 - val_mse: 1.0147
#
# Epoch 15/200
# 28/28 - 0s - loss: 1.0845 - mse: 1.0845 - val_loss: 1.0600 - val_mse: 1.0600
#
# Epoch 16/200
# 28/28 - 0s - loss: 1.1496 - mse: 1.1496 - val_loss: 1.2872 - val_mse: 1.2872
#
# Epoch 17/200
# 28/28 - 0s - loss: 1.2452 - mse: 1.2452 - val_loss: 1.0900 - val_mse: 1.0900
#
# Epoch 18/200
# 28/28 - 0s - loss: 1.1311 - mse: 1.1311 - val_loss: 0.9893 - val_mse: 0.9893
#
# Epoch 19/200
# 28/28 - 0s - loss: 1.1441 - mse: 1.1441 - val_loss: 1.0931 - val_mse: 1.0931
# Epoch 20/200
# 28/28 - 0s - loss: 1.1442 - mse: 1.1442 - val_loss: 0.9911 - val_mse: 0.9911
#
# Epoch 21/200
# 28/28 - 0s - loss: 1.0685 - mse: 1.0685 - val_loss: 1.0501 - val_mse: 1.0501
#
# Epoch 22/200
# 28/28 - 0s - loss: 1.1300 - mse: 1.1300 - val_loss: 1.0652 - val_mse: 1.0652
#
# Epoch 23/200
# 28/28 - 0s - loss: 1.1071 - mse: 1.1071 - val_loss: 1.1690 - val_mse: 1.1690
#
# Epoch 24/200
# 28/28 - 0s - loss: 1.1863 - mse: 1.1863 - val_loss: 1.1103 - val_mse: 1.1103
#
# Epoch 25/200
# 28/28 - 0s - loss: 1.1190 - mse: 1.1190 - val_loss: 0.9887 - val_mse: 0.9887
#
# Epoch 26/200
# 28/28 - 0s - loss: 1.1032 - mse: 1.1032 - val_loss: 0.9922 - val_mse: 0.9922
#
# Epoch 27/200
# 28/28 - 0s - loss: 1.0810 - mse: 1.0810 - val_loss: 1.0522 - val_mse: 1.0522
#
# Epoch 28/200
# 28/28 - 0s - loss: 1.1589 - mse: 1.1589 - val_loss: 0.9942 - val_mse: 0.9942
#
# Epoch 29/200
# 28/28 - 0s - loss: 1.0668 - mse: 1.0668 - val_loss: 1.0270 - val_mse: 1.0270
#
# Epoch 30/200
# 28/28 - 0s - loss: 1.1371 - mse: 1.1371 - val_loss: 0.9948 - val_mse: 0.9948
#
# Epoch 31/200
# 28/28 - 0s - loss: 1.1768 - mse: 1.1768 - val_loss: 1.0054 - val_mse: 1.0054
#
# Epoch 32/200
# 28/28 - 0s - loss: 1.0281 - mse: 1.0281 - val_loss: 0.9900 - val_mse: 0.9900
#
# Epoch 33/200
# 28/28 - 0s - loss: 1.1323 - mse: 1.1323 - val_loss: 1.0839 - val_mse: 1.0839
#
# Epoch 34/200
# 28/28 - 0s - loss: 1.0286 - mse: 1.0286 - val_loss: 0.9905 - val_mse: 0.9905
#
# Epoch 35/200
# 28/28 - 0s - loss: 1.0986 - mse: 1.0986 - val_loss: 1.0011 - val_mse: 1.0011
#
# Epoch 36/200
# 28/28 - 0s - loss: 1.2130 - mse: 1.2130 - val_loss: 0.9946 - val_mse: 0.9946
#
# Epoch 37/200
# 28/28 - 0s - loss: 1.0825 - mse: 1.0825 - val_loss: 0.9842 - val_mse: 0.9842
#
# Epoch 38/200
# 28/28 - 0s - loss: 1.0989 - mse: 1.0989 - val_loss: 1.0628 - val_mse: 1.0628
#
# Epoch 39/200
# 28/28 - 0s - loss: 1.0809 - mse: 1.0809 - val_loss: 0.9887 - val_mse: 0.9887
#
# Epoch 40/200
# 28/28 - 0s - loss: 1.1309 - mse: 1.1309 - val_loss: 1.0109 - val_mse: 1.0109
#
# Epoch 41/200
# 28/28 - 0s - loss: 1.0943 - mse: 1.0943 - val_loss: 0.9843 - val_mse: 0.9843
#
# Epoch 42/200
# 28/28 - 0s - loss: 1.1439 - mse: 1.1439 - val_loss: 1.0087 - val_mse: 1.0087
#
# Epoch 43/200
# 28/28 - 0s - loss: 1.1290 - mse: 1.1290 - val_loss: 1.0646 - val_mse: 1.0646
#
# Epoch 44/200
# 28/28 - 0s - loss: 1.1205 - mse: 1.1205 - val_loss: 1.1290 - val_mse: 1.1290
#
# Epoch 45/200
# 28/28 - 0s - loss: 1.1204 - mse: 1.1204 - val_loss: 1.1101 - val_mse: 1.1101
#
# Epoch 46/200
# 28/28 - 0s - loss: 1.0985 - mse: 1.0985 - val_loss: 1.0053 - val_mse: 1.0053
#
# Epoch 47/200
# 28/28 - 0s - loss: 1.0937 - mse: 1.0937 - val_loss: 1.0800 - val_mse: 1.0800
#
# Epoch 48/200
# 28/28 - 0s - loss: 1.1404 - mse: 1.1404 - val_loss: 1.0006 - val_mse: 1.0006
#
# Epoch 49/200
# 28/28 - 0s - loss: 1.1443 - mse: 1.1443 - val_loss: 1.1934 - val_mse: 1.1934
#
# Epoch 50/200
# 28/28 - 0s - loss: 1.1183 - mse: 1.1183 - val_loss: 1.0002 - val_mse: 1.0002
#
# Epoch 51/200
# 28/28 - 0s - loss: 1.0761 - mse: 1.0761 - val_loss: 1.0094 - val_mse: 1.0094
#
# Epoch 52/200
# 28/28 - 0s - loss: 1.1184 - mse: 1.1184 - val_loss: 1.0307 - val_mse: 1.0307
#
# Epoch 53/200
# 28/28 - 0s - loss: 1.1166 - mse: 1.1166 - val_loss: 0.9879 - val_mse: 0.9879
#
# Epoch 54/200
# 28/28 - 0s - loss: 1.0833 - mse: 1.0833 - val_loss: 1.0516 - val_mse: 1.0516
#
# Epoch 55/200
# 28/28 - 0s - loss: 1.1151 - mse: 1.1151 - val_loss: 0.9935 - val_mse: 0.9935
#
# Epoch 56/200
# 28/28 - 0s - loss: 1.1576 - mse: 1.1576 - val_loss: 0.9911 - val_mse: 0.9911
#
# Epoch 57/200
# 28/28 - 0s - loss: 1.1111 - mse: 1.1111 - val_loss: 1.2750 - val_mse: 1.2750
#
# Epoch 58/200
# 28/28 - 0s - loss: 1.0886 - mse: 1.0886 - val_loss: 1.0065 - val_mse: 1.0065
#
# Epoch 59/200
# 28/28 - 0s - loss: 1.0866 - mse: 1.0866 - val_loss: 0.9920 - val_mse: 0.9920
#
# Epoch 60/200
# 28/28 - 0s - loss: 1.1109 - mse: 1.1109 - val_loss: 1.0488 - val_mse: 1.0488
#
# Epoch 61/200
# 28/28 - 0s - loss: 1.0943 - mse: 1.0943 - val_loss: 1.0778 - val_mse: 1.0778
#
# Epoch 62/200
# 28/28 - 0s - loss: 1.1066 - mse: 1.1066 - val_loss: 1.0288 - val_mse: 1.0288
#
# Epoch 63/200
# 28/28 - 0s - loss: 1.1104 - mse: 1.1104 - val_loss: 1.0253 - val_mse: 1.0253
#
# Epoch 64/200
# 28/28 - 0s - loss: 1.0634 - mse: 1.0634 - val_loss: 1.1094 - val_mse: 1.1094
#
# Epoch 65/200
# 28/28 - 0s - loss: 1.1074 - mse: 1.1074 - val_loss: 0.9785 - val_mse: 0.9785
#
# Epoch 66/200
# 28/28 - 0s - loss: 1.0874 - mse: 1.0874 - val_loss: 0.9960 - val_mse: 0.9960
#
# Epoch 67/200
# 28/28 - 0s - loss: 1.0844 - mse: 1.0844 - val_loss: 1.4060 - val_mse: 1.4060
#
# Epoch 68/200
# 28/28 - 0s - loss: 1.2137 - mse: 1.2137 - val_loss: 0.9995 - val_mse: 0.9995
#
# Epoch 69/200
# 28/28 - 0s - loss: 1.0819 - mse: 1.0819 - val_loss: 1.0460 - val_mse: 1.0460
#
# Epoch 70/200
# 28/28 - 0s - loss: 1.1110 - mse: 1.1110 - val_loss: 1.1045 - val_mse: 1.1045
#
# Epoch 71/200
# 28/28 - 0s - loss: 1.0675 - mse: 1.0675 - val_loss: 0.9939 - val_mse: 0.9939
#
# Epoch 72/200
# 28/28 - 0s - loss: 1.0992 - mse: 1.0992 - val_loss: 1.0535 - val_mse: 1.0535
#
# Epoch 73/200
# 28/28 - 0s - loss: 1.0907 - mse: 1.0907 - val_loss: 1.0552 - val_mse: 1.0552
#
# Epoch 74/200
# 28/28 - 0s - loss: 1.1497 - mse: 1.1497 - val_loss: 1.0343 - val_mse: 1.0343
#
# Epoch 75/200
# 28/28 - 0s - loss: 1.0577 - mse: 1.0577 - val_loss: 1.0463 - val_mse: 1.0463
#
# Epoch 76/200
# 28/28 - 0s - loss: 1.0401 - mse: 1.0401 - val_loss: 1.0974 - val_mse: 1.0974
#
# Epoch 77/200
# 28/28 - 0s - loss: 1.1057 - mse: 1.1057 - val_loss: 1.3326 - val_mse: 1.3326
#
# Epoch 78/200
# 28/28 - 0s - loss: 1.0667 - mse: 1.0667 - val_loss: 0.9966 - val_mse: 0.9966
#
# Epoch 79/200
# 28/28 - 0s - loss: 1.0894 - mse: 1.0894 - val_loss: 0.9934 - val_mse: 0.9934
#
# Epoch 80/200
# 28/28 - 0s - loss: 1.1115 - mse: 1.1115 - val_loss: 1.0814 - val_mse: 1.0814
#
# Epoch 81/200
# 28/28 - 0s - loss: 1.1394 - mse: 1.1394 - val_loss: 0.9800 - val_mse: 0.9800
#
# Epoch 82/200
# 28/28 - 0s - loss: 1.1576 - mse: 1.1576 - val_loss: 1.0047 - val_mse: 1.0047
#
# Epoch 83/200
# 28/28 - 0s - loss: 1.0386 - mse: 1.0386 - val_loss: 1.2562 - val_mse: 1.2562
#
# Epoch 84/200
# 28/28 - 0s - loss: 1.1297 - mse: 1.1297 - val_loss: 1.2736 - val_mse: 1.2736
#
# Epoch 85/200
# 28/28 - 0s - loss: 1.1289 - mse: 1.1289 - val_loss: 0.9801 - val_mse: 0.9801
#
# Epoch 86/200
# 28/28 - 0s - loss: 1.0520 - mse: 1.0520 - val_loss: 0.9739 - val_mse: 0.9739
# Epoch 87/200
# 28/28 - 0s - loss: 1.0865 - mse: 1.0865 - val_loss: 0.9886 - val_mse: 0.9886
#
# Epoch 88/200
# 28/28 - 0s - loss: 1.1298 - mse: 1.1298 - val_loss: 1.1027 - val_mse: 1.1027
#
# Epoch 89/200
# 28/28 - 0s - loss: 1.0654 - mse: 1.0654 - val_loss: 0.9695 - val_mse: 0.9695
#
# Epoch 90/200
# 28/28 - 0s - loss: 1.1750 - mse: 1.1750 - val_loss: 0.9736 - val_mse: 0.9736
#
# Epoch 91/200
# 28/28 - 0s - loss: 1.1334 - mse: 1.1334 - val_loss: 1.0213 - val_mse: 1.0213
#
# Epoch 92/200
# 28/28 - 0s - loss: 1.1134 - mse: 1.1134 - val_loss: 1.0114 - val_mse: 1.0114
#
# Epoch 93/200
# 28/28 - 0s - loss: 1.0703 - mse: 1.0703 - val_loss: 1.0449 - val_mse: 1.0449
#
# Epoch 94/200
# 28/28 - 0s - loss: 1.1400 - mse: 1.1400 - val_loss: 1.1274 - val_mse: 1.1274
#
# Epoch 95/200
# 28/28 - 0s - loss: 1.0247 - mse: 1.0247 - val_loss: 0.9828 - val_mse: 0.9828
#
# Epoch 96/200
# 28/28 - 0s - loss: 1.1480 - mse: 1.1480 - val_loss: 0.9743 - val_mse: 0.9743
#
# Epoch 97/200
# 28/28 - 0s - loss: 1.0681 - mse: 1.0681 - val_loss: 0.9943 - val_mse: 0.9943
#
# Epoch 98/200
# 28/28 - 0s - loss: 1.1086 - mse: 1.1086 - val_loss: 1.0021 - val_mse: 1.0021
#
# Epoch 99/200
# 28/28 - 0s - loss: 1.0935 - mse: 1.0935 - val_loss: 0.9833 - val_mse: 0.9833
#
# Epoch 100/200
# 28/28 - 0s - loss: 1.1069 - mse: 1.1069 - val_loss: 0.9795 - val_mse: 0.9795
#
# Epoch 101/200
# 28/28 - 0s - loss: 1.1359 - mse: 1.1359 - val_loss: 1.0290 - val_mse: 1.0290
#
# Epoch 102/200
# 28/28 - 0s - loss: 1.1483 - mse: 1.1483 - val_loss: 1.2865 - val_mse: 1.2865
#
# Epoch 103/200
# 28/28 - 0s - loss: 1.1018 - mse: 1.1018 - val_loss: 0.9765 - val_mse: 0.9765
#
# Epoch 104/200
# 28/28 - 0s - loss: 1.1046 - mse: 1.1046 - val_loss: 1.1123 - val_mse: 1.1123
#
# Epoch 105/200
# 28/28 - 0s - loss: 1.0995 - mse: 1.0995 - val_loss: 1.2494 - val_mse: 1.2494
#
# Epoch 106/200
# 28/28 - 0s - loss: 1.1472 - mse: 1.1472 - val_loss: 1.0648 - val_mse: 1.0648
#
# Epoch 107/200
# 28/28 - 0s - loss: 1.0465 - mse: 1.0465 - val_loss: 1.0495 - val_mse: 1.0495
#
# Epoch 108/200
# 28/28 - 0s - loss: 1.0307 - mse: 1.0307 - val_loss: 0.9994 - val_mse: 0.9994
#
# Epoch 109/200
# 28/28 - 0s - loss: 1.0930 - mse: 1.0930 - val_loss: 0.9774 - val_mse: 0.9774
#
# Epoch 110/200
# 28/28 - 0s - loss: 1.0500 - mse: 1.0500 - val_loss: 0.9969 - val_mse: 0.9969
#
# Epoch 111/200
# 28/28 - 0s - loss: 1.1251 - mse: 1.1251 - val_loss: 1.1157 - val_mse: 1.1157
#
# Epoch 112/200
# 28/28 - 0s - loss: 1.0527 - mse: 1.0527 - val_loss: 0.9640 - val_mse: 0.9640
#
# Epoch 113/200
# 28/28 - 0s - loss: 1.0612 - mse: 1.0612 - val_loss: 0.9815 - val_mse: 0.9815
#
# Epoch 114/200
# 28/28 - 0s - loss: 1.0789 - mse: 1.0789 - val_loss: 0.9963 - val_mse: 0.9963
#
# Epoch 115/200
# 28/28 - 0s - loss: 1.0521 - mse: 1.0521 - val_loss: 1.0250 - val_mse: 1.0250
#
# Epoch 116/200
# 28/28 - 0s - loss: 1.0920 - mse: 1.0920 - val_loss: 0.9852 - val_mse: 0.9852
#
# Epoch 117/200
# 28/28 - 0s - loss: 1.0127 - mse: 1.0127 - val_loss: 1.0266 - val_mse: 1.0266
#
# Epoch 118/200
# 28/28 - 0s - loss: 1.1610 - mse: 1.1610 - val_loss: 0.9652 - val_mse: 0.9652
#
# Epoch 119/200
# 28/28 - 0s - loss: 1.1153 - mse: 1.1153 - val_loss: 1.2042 - val_mse: 1.2042
#
# Epoch 120/200
# 28/28 - 0s - loss: 0.9998 - mse: 0.9998 - val_loss: 0.9775 - val_mse: 0.9775
#
# Epoch 121/200
# 28/28 - 0s - loss: 1.1030 - mse: 1.1030 - val_loss: 1.0024 - val_mse: 1.0024
#
# Epoch 122/200
# 28/28 - 0s - loss: 1.1533 - mse: 1.1533 - val_loss: 0.9724 - val_mse: 0.9724
#
# Epoch 123/200
# 28/28 - 0s - loss: 1.1348 - mse: 1.1348 - val_loss: 0.9747 - val_mse: 0.9747
#
# Epoch 124/200
# 28/28 - 0s - loss: 1.0434 - mse: 1.0434 - val_loss: 0.9834 - val_mse: 0.9834
#
# Epoch 125/200
# 28/28 - 0s - loss: 1.1416 - mse: 1.1416 - val_loss: 1.0212 - val_mse: 1.0212
#
# Epoch 126/200
# 28/28 - 0s - loss: 1.0799 - mse: 1.0799 - val_loss: 1.1888 - val_mse: 1.1888
#
# Epoch 127/200
# 28/28 - 0s - loss: 1.1271 - mse: 1.1271 - val_loss: 0.9782 - val_mse: 0.9782
#
# Epoch 128/200
# 28/28 - 0s - loss: 1.1553 - mse: 1.1553 - val_loss: 1.0367 - val_mse: 1.0367
#
# Epoch 129/200
# 28/28 - 0s - loss: 1.0424 - mse: 1.0424 - val_loss: 1.0197 - val_mse: 1.0197
#
# Epoch 130/200
# 28/28 - 0s - loss: 1.1805 - mse: 1.1805 - val_loss: 0.9637 - val_mse: 0.9637
#
# Epoch 131/200
# 28/28 - 0s - loss: 1.0519 - mse: 1.0519 - val_loss: 1.0014 - val_mse: 1.0014
#
# Epoch 132/200
# 28/28 - 0s - loss: 1.0318 - mse: 1.0318 - val_loss: 0.9915 - val_mse: 0.9915
#
# Epoch 133/200
# 28/28 - 0s - loss: 1.0809 - mse: 1.0809 - val_loss: 1.0539 - val_mse: 1.0539
#
# Epoch 134/200
# 28/28 - 0s - loss: 1.1700 - mse: 1.1700 - val_loss: 0.9724 - val_mse: 0.9724
#
# Epoch 135/200
# 28/28 - 0s - loss: 1.0566 - mse: 1.0566 - val_loss: 1.0302 - val_mse: 1.0302
#
# Epoch 136/200
# 28/28 - 0s - loss: 1.1786 - mse: 1.1786 - val_loss: 0.9744 - val_mse: 0.9744
#
# Epoch 137/200
# 28/28 - 0s - loss: 1.0009 - mse: 1.0009 - val_loss: 0.9754 - val_mse: 0.9754
#
# Epoch 138/200
# 28/28 - 0s - loss: 1.1048 - mse: 1.1048 - val_loss: 0.9985 - val_mse: 0.9985
#
# Epoch 139/200
# 28/28 - 0s - loss: 1.1369 - mse: 1.1369 - val_loss: 1.0083 - val_mse: 1.0083
#
# Epoch 140/200
# 28/28 - 0s - loss: 1.0857 - mse: 1.0857 - val_loss: 1.0698 - val_mse: 1.0698
#
# Epoch 141/200
# 28/28 - 0s - loss: 1.0731 - mse: 1.0731 - val_loss: 0.9804 - val_mse: 0.9804
#
# Epoch 142/200
# 28/28 - 0s - loss: 1.0550 - mse: 1.0550 - val_loss: 0.9557 - val_mse: 0.9557
#
# Epoch 143/200
# 28/28 - 0s - loss: 1.1491 - mse: 1.1491 - val_loss: 1.0695 - val_mse: 1.0695
#
# Epoch 144/200
# 28/28 - 0s - loss: 1.0537 - mse: 1.0537 - val_loss: 1.1499 - val_mse: 1.1499
#
# Epoch 145/200
# 28/28 - 0s - loss: 1.1280 - mse: 1.1280 - val_loss: 0.9596 - val_mse: 0.9596
#
# Epoch 146/200
# 28/28 - 0s - loss: 1.1007 - mse: 1.1007 - val_loss: 0.9931 - val_mse: 0.9931
#
# Epoch 147/200
# 28/28 - 0s - loss: 1.1564 - mse: 1.1564 - val_loss: 0.9793 - val_mse: 0.9793
#
# Epoch 148/200
# 28/28 - 0s - loss: 1.0689 - mse: 1.0689 - val_loss: 0.9847 - val_mse: 0.9847
#
# Epoch 149/200
# 28/28 - 0s - loss: 1.0578 - mse: 1.0578 - val_loss: 1.0922 - val_mse: 1.0922
#
# Epoch 150/200
# 28/28 - 0s - loss: 1.2116 - mse: 1.2116 - val_loss: 1.0978 - val_mse: 1.0978
#
# Epoch 151/200
# 28/28 - 0s - loss: 1.0742 - mse: 1.0742 - val_loss: 0.9819 - val_mse: 0.9819
#
# Epoch 152/200
# 28/28 - 0s - loss: 1.0554 - mse: 1.0554 - val_loss: 1.0478 - val_mse: 1.0478
#
# Epoch 153/200
# 28/28 - 0s - loss: 1.1524 - mse: 1.1524 - val_loss: 0.9899 - val_mse: 0.9899
# Epoch 154/200
# 28/28 - 0s - loss: 1.0903 - mse: 1.0903 - val_loss: 0.9818 - val_mse: 0.9818
#
# Epoch 155/200
# 28/28 - 0s - loss: 1.1562 - mse: 1.1562 - val_loss: 1.1074 - val_mse: 1.1074
#
# Epoch 156/200
# 28/28 - 0s - loss: 1.1095 - mse: 1.1095 - val_loss: 0.9695 - val_mse: 0.9695
#
# Epoch 157/200
# 28/28 - 0s - loss: 1.0902 - mse: 1.0902 - val_loss: 0.9967 - val_mse: 0.9967
#
# Epoch 158/200
# 28/28 - 0s - loss: 1.0616 - mse: 1.0616 - val_loss: 0.9987 - val_mse: 0.9987
#
# Epoch 159/200
# 28/28 - 0s - loss: 1.1173 - mse: 1.1173 - val_loss: 1.2396 - val_mse: 1.2396
#
# Epoch 160/200
# 28/28 - 0s - loss: 1.0527 - mse: 1.0527 - val_loss: 1.1408 - val_mse: 1.1408
#
# Epoch 161/200
# 28/28 - 0s - loss: 1.0705 - mse: 1.0705 - val_loss: 0.9855 - val_mse: 0.9855
#
# Epoch 162/200
# 28/28 - 0s - loss: 1.0615 - mse: 1.0615 - val_loss: 0.9581 - val_mse: 0.9581
#
# Epoch 163/200
# 28/28 - 0s - loss: 1.1386 - mse: 1.1386 - val_loss: 0.9570 - val_mse: 0.9570
#
# Epoch 164/200
# 28/28 - 0s - loss: 1.0664 - mse: 1.0664 - val_loss: 0.9639 - val_mse: 0.9639
#
# Epoch 165/200
# 28/28 - 0s - loss: 1.0539 - mse: 1.0539 - val_loss: 1.0259 - val_mse: 1.0259
#
# Epoch 166/200
# 28/28 - 0s - loss: 1.0981 - mse: 1.0981 - val_loss: 0.9584 - val_mse: 0.9584
#
# Epoch 167/200
# 28/28 - 0s - loss: 1.0420 - mse: 1.0420 - val_loss: 0.9675 - val_mse: 0.9675
#
# Epoch 168/200
# 28/28 - 0s - loss: 1.0893 - mse: 1.0893 - val_loss: 1.2375 - val_mse: 1.2375
#
# Epoch 169/200
# 28/28 - 0s - loss: 1.1219 - mse: 1.1219 - val_loss: 1.1260 - val_mse: 1.1260
#
# Epoch 170/200
# 28/28 - 0s - loss: 1.0671 - mse: 1.0671 - val_loss: 1.0547 - val_mse: 1.0547
#
# Epoch 171/200
# 28/28 - 0s - loss: 1.1174 - mse: 1.1174 - val_loss: 0.9646 - val_mse: 0.9646
#
# Epoch 172/200
# 28/28 - 0s - loss: 1.0580 - mse: 1.0580 - val_loss: 0.9967 - val_mse: 0.9967
#
# Epoch 173/200
# 28/28 - 0s - loss: 1.0880 - mse: 1.0880 - val_loss: 0.9800 - val_mse: 0.9800
#
# Epoch 174/200
# 28/28 - 0s - loss: 1.0523 - mse: 1.0523 - val_loss: 0.9692 - val_mse: 0.9692
#
# Epoch 175/200
# 28/28 - 0s - loss: 1.1063 - mse: 1.1063 - val_loss: 1.0248 - val_mse: 1.0248
#
# Epoch 176/200
# 28/28 - 0s - loss: 1.0231 - mse: 1.0231 - val_loss: 0.9951 - val_mse: 0.9951
#
# Epoch 177/200
# 28/28 - 0s - loss: 1.1133 - mse: 1.1133 - val_loss: 0.9898 - val_mse: 0.9898
#
# Epoch 178/200
# 28/28 - 0s - loss: 1.0781 - mse: 1.0781 - val_loss: 0.9884 - val_mse: 0.9884
#
# Epoch 179/200
# 28/28 - 0s - loss: 1.0746 - mse: 1.0746 - val_loss: 0.9688 - val_mse: 0.9688
#
# Epoch 180/200
# 28/28 - 0s - loss: 1.0391 - mse: 1.0391 - val_loss: 0.9742 - val_mse: 0.9742
#
# Epoch 181/200
# 28/28 - 0s - loss: 1.0937 - mse: 1.0937 - val_loss: 0.9773 - val_mse: 0.9773
#
# Epoch 182/200
# 28/28 - 0s - loss: 1.0877 - mse: 1.0877 - val_loss: 1.1620 - val_mse: 1.1620
#
# Epoch 183/200
# 28/28 - 0s - loss: 1.0865 - mse: 1.0865 - val_loss: 0.9704 - val_mse: 0.9704
#
# Epoch 184/200
# 28/28 - 0s - loss: 1.0619 - mse: 1.0619 - val_loss: 0.9982 - val_mse: 0.9982
#
# Epoch 185/200
# 28/28 - 0s - loss: 1.0556 - mse: 1.0556 - val_loss: 0.9548 - val_mse: 0.9548
#
# Epoch 186/200
# ...
#
# Epoch 65/100
# 3/3 - 0s - loss: 0.2096 - mse: 0.2096 - val_loss: 0.1769 - val_mse: 0.1769
#
# Epoch 66/100
# 3/3 - 0s - loss: 0.2138 - mse: 0.2138 - val_loss: 0.1766 - val_mse: 0.1766
#
# Epoch 67/100
# 3/3 - 0s - loss: 0.2035 - mse: 0.2035 - val_loss: 0.1763 - val_mse: 0.1763
#
# Epoch 68/100
# 3/3 - 0s - loss: 0.2048 - mse: 0.2048 - val_loss: 0.1761 - val_mse: 0.1761
#
# Epoch 69/100
# 3/3 - 0s - loss: 0.2122 - mse: 0.2122 - val_loss: 0.1752 - val_mse: 0.1752
#
# Epoch 70/100
# 3/3 - 0s - loss: 0.2021 - mse: 0.2021 - val_loss: 0.1744 - val_mse: 0.1744
#
# Epoch 71/100
# 3/3 - 0s - loss: 0.2050 - mse: 0.2050 - val_loss: 0.1736 - val_mse: 0.1736
#
# Epoch 72/100
# 3/3 - 0s - loss: 0.2020 - mse: 0.2020 - val_loss: 0.1729 - val_mse: 0.1729
#
# Epoch 73/100
# 3/3 - 0s - loss: 0.1970 - mse: 0.1970 - val_loss: 0.1717 - val_mse: 0.1717
#
# Epoch 74/100
# 3/3 - 0s - loss: 0.1964 - mse: 0.1964 - val_loss: 0.1701 - val_mse: 0.1701
#
# Epoch 75/100
# 3/3 - 0s - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1688 - val_mse: 0.1688
#
# Epoch 76/100
# 3/3 - 0s - loss: 0.1932 - mse: 0.1932 - val_loss: 0.1674 - val_mse: 0.1674
#
# Epoch 77/100
# 3/3 - 0s - loss: 0.1904 - mse: 0.1904 - val_loss: 0.1663 - val_mse: 0.1663
#
# Epoch 78/100
# 3/3 - 0s - loss: 0.1860 - mse: 0.1860 - val_loss: 0.1652 - val_mse: 0.1652
#
# Epoch 79/100
# 3/3 - 0s - loss: 0.1916 - mse: 0.1916 - val_loss: 0.1640 - val_mse: 0.1640
#
# Epoch 80/100
# 3/3 - 0s - loss: 0.1931 - mse: 0.1931 - val_loss: 0.1629 - val_mse: 0.1629
#
# Epoch 81/100
# 3/3 - 0s - loss: 0.1858 - mse: 0.1858 - val_loss: 0.1616 - val_mse: 0.1616
#
# Epoch 82/100
# 3/3 - 0s - loss: 0.1867 - mse: 0.1867 - val_loss: 0.1597 - val_mse: 0.1597
#
# Epoch 83/100
# 3/3 - 0s - loss: 0.1876 - mse: 0.1876 - val_loss: 0.1580 - val_mse: 0.1580
#
# Epoch 84/100
# 3/3 - 0s - loss: 0.1785 - mse: 0.1785 - val_loss: 0.1569 - val_mse: 0.1569
#
# Epoch 85/100
# 3/3 - 0s - loss: 0.1847 - mse: 0.1847 - val_loss: 0.1559 - val_mse: 0.1559
#
# Epoch 86/100
# 3/3 - 0s - loss: 0.1749 - mse: 0.1749 - val_loss: 0.1547 - val_mse: 0.1547
#
# Epoch 87/100
# 3/3 - 0s - loss: 0.1849 - mse: 0.1849 - val_loss: 0.1539 - val_mse: 0.1539
#
# Epoch 88/100
# 3/3 - 0s - loss: 0.1773 - mse: 0.1773 - val_loss: 0.1532 - val_mse: 0.1532
#
# Epoch 89/100
# 3/3 - 0s - loss: 0.1763 - mse: 0.1763 - val_loss: 0.1524 - val_mse: 0.1524
#
# Epoch 90/100
# 3/3 - 0s - loss: 0.1794 - mse: 0.1794 - val_loss: 0.1513 - val_mse: 0.1513
#
# Epoch 91/100
# 3/3 - 0s - loss: 0.1754 - mse: 0.1754 - val_loss: 0.1500 - val_mse: 0.1500
#
# Epoch 92/100
# 3/3 - 0s - loss: 0.1721 - mse: 0.1721 - val_loss: 0.1494 - val_mse: 0.1494
#
# Epoch 93/100
# 3/3 - 0s - loss: 0.1696 - mse: 0.1696 - val_loss: 0.1489 - val_mse: 0.1489
# Epoch 94/100
# 3/3 - 0s - loss: 0.1718 - mse: 0.1718 - val_loss: 0.1488 - val_mse: 0.1488
#
# Epoch 95/100
# 3/3 - 0s - loss: 0.1671 - mse: 0.1671 - val_loss: 0.1486 - val_mse: 0.1486
#
# Epoch 96/100
# 3/3 - 0s - loss: 0.1714 - mse: 0.1714 - val_loss: 0.1483 - val_mse: 0.1483
#
# Epoch 97/100
# 3/3 - 0s - loss: 0.1708 - mse: 0.1708 - val_loss: 0.1476 - val_mse: 0.1476
#
# Epoch 98/100
# 3/3 - 0s - loss: 0.1726 - mse: 0.1726 - val_loss: 0.1466 - val_mse: 0.1466
#
# Epoch 99/100
# 3/3 - 0s - loss: 0.1634 - mse: 0.1634 - val_loss: 0.1449 - val_mse: 0.1449
#
# Epoch 100/100
# 3/3 - 0s - loss: 0.1573 - mse: 0.1573 - val_loss: 0.1434 - val_mse: 0.1434
#
# Test accuracy:
# 0.14344757795333862
# 100%|███████████████████████████████████████████████| 10/10 [04:52<00:00, 29.24s/trial, best loss: 0.07978055626153946]
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 0.9616051316261292, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F0EFC75E0>}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [0], 'Dropout': [0], 'batch_size': [0], 'epochs': [0], 'optimizer': [0]}, 'vals': {'Activation': [1], 'Dropout': [0.692539034315719], 'batch_size': [0], 'epochs': [1], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 9, 36, 354000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 10, 1, 314000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 0.08856160938739777, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F0EFC73D0>}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [1], 'Dropout': [1], 'batch_size': [1], 'epochs': [1], 'optimizer': [1]}, 'vals': {'Activation': [2], 'Dropout': [0.8366666847115819], 'batch_size': [0], 'epochs': [1], 'optimizer': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 10, 1, 322000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 10, 28, 90000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 0.42156660556793213, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F16AC2CA0>}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [2], 'Dropout': [2], 'batch_size': [2], 'epochs': [2], 'optimizer': [2]}, 'vals': {'Activation': [1], 'Dropout': [0.7275581656084844], 'batch_size': [2], 'epochs': [2], 'optimizer': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 10, 28, 96000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 10, 55, 345000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 0.07978055626153946, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F574D6220>}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [3], 'Dropout': [3], 'batch_size': [3], 'epochs': [3], 'optimizer': [3]}, 'vals': {'Activation': [2], 'Dropout': [0.7646166765488501], 'batch_size': [2], 'epochs': [1], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 10, 55, 350000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 11, 14, 277000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 0.4125259518623352, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F07C965E0>}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [4], 'Dropout': [4], 'batch_size': [4], 'epochs': [4], 'optimizer': [4]}, 'vals': {'Activation': [3], 'Dropout': [0.2330896882313117], 'batch_size': [3], 'epochs': [4], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 11, 14, 282000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 11, 52, 495000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 0.23575074970722198, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F6ADC7A00>}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [5], 'Dropout': [5], 'batch_size': [5], 'epochs': [5], 'optimizer': [5]}, 'vals': {'Activation': [0], 'Dropout': [0.6883693507416478], 'batch_size': [2], 'epochs': [2], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 11, 52, 500000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 12, 18, 310000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 0.2333713173866272, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F09900E80>}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [6], 'Dropout': [6], 'batch_size': [6], 'epochs': [6], 'optimizer': [6]}, 'vals': {'Activation': [2], 'Dropout': [0.39730440328653105], 'batch_size': [0], 'epochs': [3], 'optimizer': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 12, 18, 315000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 13, 12, 660000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 0.15242458879947662, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F782BF790>}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [7], 'Dropout': [7], 'batch_size': [7], 'epochs': [7], 'optimizer': [7]}, 'vals': {'Activation': [0], 'Dropout': [0.258985915829989], 'batch_size': [1], 'epochs': [3], 'optimizer': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 13, 12, 666000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 13, 51, 329000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 0.3963562846183777, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F6F64B820>}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [8], 'Dropout': [8], 'batch_size': [8], 'epochs': [8], 'optimizer': [8]}, 'vals': {'Activation': [3], 'Dropout': [0.06528675004895668], 'batch_size': [2], 'epochs': [2], 'optimizer': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 13, 51, 335000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 14, 18, 821000)}
# {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': 0.14344757795333862, 'status': 'ok', 'model': <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000020F1893AF10>}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'Activation': [9], 'Dropout': [9], 'batch_size': [9], 'epochs': [9], 'optimizer': [9]}, 'vals': {'Activation': [0], 'Dropout': [0.20946774700477522], 'batch_size': [3], 'epochs': [0], 'optimizer': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 1, 15, 21, 14, 18, 827000), 'refresh_time': datetime.datetime(2021, 1, 15, 21, 14, 28, 765000)}
# Evalutation of best performing model:
# 4/4 [==============================] - ETA: 0s - loss: 0.0919 - mse: 0.091 - 0s 2ms/step - loss: 0.0798 - mse: 0.0798
# [0.07978055626153946, 0.07978055626153946]
# Best performing model chosen hyper-parameters:
# {'Activation': 2, 'Dropout': 0.7646166765488501, 'batch_size': 2, 'epochs': 1, 'optimizer': 3}
